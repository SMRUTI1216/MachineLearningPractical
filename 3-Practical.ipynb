# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("smart_class_energy_data.csv")

# %%
data.head()
# Out:
#    Num_Students  Outdoor_Temp Time_of_Day   Humidity  Lights_On  Windows_Open  \
# 0            33     34.714868     Morning  69.221654          1             0
# 1            73     27.689434     Evening  75.267053          1             1
# 2            73     38.544262   Afternoon  69.683302          0             0
# 3             7     33.203330     Evening  89.243701          1             0
# 4            35     33.565462     Evening  68.174341          0             0
#
#    Fan_Speed    AC_Temp
# 0          2  26.911474
# 1          4  22.531882
# 2          3  23.523407
# 3          4  22.411541
# 4          1  26.139862

# %%
data.describe()
# Out:
#        Num_Students  Outdoor_Temp    Humidity   Lights_On  Windows_Open  \
# count    500.000000    500.000000  500.000000  500.000000    500.000000
# mean      49.218000     29.742121   61.601151    0.526000      0.490000
# std       28.134491      5.708421   16.924468    0.499824      0.500401
# min        5.000000     20.088729   30.145123    0.000000      0.000000
# 25%       25.000000     24.796337   47.449764    0.000000      0.000000
# 50%       46.000000     29.785890   62.974976    1.000000      0.000000
# 75%       74.000000     34.309672   75.977499    1.000000      1.000000
# max      100.000000     39.930563   89.911184    1.000000      1.000000
#
#         Fan_Speed     AC_Temp
# count  500.000000  500.000000
# mean     3.478000   22.984699
# std      1.201834    2.064986
# min      1.000000   20.006094
# 25%      3.000000   21.298244
# 50%      3.000000   22.656177
# 75%      4.000000   24.200886
# max      5.000000   27.995065

# %%
data.dropna()
# Out:
#      Num_Students  Outdoor_Temp Time_of_Day   Humidity  Lights_On  \
# 0              33     34.714868     Morning  69.221654          1
# 1              73     27.689434     Evening  75.267053          1
# 2              73     38.544262   Afternoon  69.683302          0
# 3               7     33.203330     Evening  89.243701          1
# 4              35     33.565462     Evening  68.174341          0
# ..            ...           ...         ...        ...        ...
# 495            31     35.311169     Evening  71.632427          1
# 496            62     33.835296     Evening  77.747009          1
# 497            47     26.515593   Afternoon  78.597107          0
# 498            33     35.886481   Afternoon  59.353728          1
# 499            85     28.043010   Afternoon  58.647936          1
#
#      Windows_Open  Fan_Speed    AC_Temp
# 0               0          2  26.911474
# 1               1          4  22.531882
# 2               0          3  23.523407
# 3               0          4  22.411541
# 4               0          1  26.139862
# ..            ...        ...        ...
# 495             1          3  23.411115
# 496             0          4  21.676222
# 497             1          4  20.370864
# 498             1          5  20.237912
# 499             0          3  21.762938
#
# [500 rows x 8 columns]

# %%
x = data[['Outdoor_Temp']]  
y = data['AC_Temp']

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=20,random_state=40)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
print("Slope (m):", model.coef_[0])
print("Intercept (c):", model.intercept_)
# Out:
# Slope (m): -0.06745279561106181
# Intercept (c): 25.013068362056252

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# 4.150078195321436

# %%
r2=r2_score(y_test,y_pred)
print(r2)
# Out:
# -0.06350612842743275

# %%
plt.scatter(x_test, y_test)
plt.plot(x_test, y_pred)
plt.xlabel("Outdoor_Temp")
plt.ylabel("AC_Temp")
plt.title("Simple Linear Regression")
plt.show()
