# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("chd.csv")

# %%
print(data.head())
# Out:
#    Obs  ID  AGE  agrp  CHD
# 0    1   1   20     1    0
# 1    2   2   23     1    0
# 2    3   3   24     1    0
# 3    4   4   25     1    0
# 4    5   5   25     1    1

# %%
import numpy as np


X = np.array([1, 2, 3, 4, 5], dtype=float)
y = np.array([2, 4, 6, 8, 10], dtype=float)


X = (X - np.mean(X)) / np.std(X)
y = (y - np.mean(y)) / np.std(y)


m, b = 0.0, 0.0
learning_rate = 0.001   
epochs = 1000
n = float(len(X))

for i in range(epochs):
    y_pred = m * X + b
    D_m = (-2/n) * np.dot(X, (y - y_pred))   
    D_b = (-2/n) * np.sum(y - y_pred)
    m = m - learning_rate * D_m
    b = b - learning_rate * D_b
    
    

print("Final slope (m):", m)
print("Final intercept (b):", b)
# Out:
# Final slope (m): 0.8649354775533157
# Final intercept (b): 2.575717417130366e-18

# %%
plt.scatter(X, y, color='blue', label='Data Points')
plt.plot(X, m*X + b, color='red', label='Regression Line')
plt.xlabel('Feature')
plt.ylabel('Label')
plt.title('Linear Regression using Gradient Descent')
plt.legend()
plt.show()

# %%
mse = np.mean((y - y_pred) ** 2)
print("Mean square error: ", mse)
# Out:
# Mean square error:  0.018315614418969117
